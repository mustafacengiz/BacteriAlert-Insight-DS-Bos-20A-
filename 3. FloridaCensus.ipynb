# %% [markdown]
# In this notebook we clean Florida census data to have the population as a demogrpahic feature for our machine learning model.

# %% [markdown]
# # 1. Loading Data

# %%
#importing useful libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#loading the data
data = pd.read_excel('2010Census_RedistrictingFile_Table1.xls')

# %%
data.head(10)
# Out:
#               Florida Legislative Office of         Unnamed: 1  \
# 0         Economic and Demographic Research                NaN
# 1                      Phone:  850.487.1402                NaN
# 2              Web:  http://edr.state.fl.us                NaN
# 3                                   Table 1                NaN
# 4          Total Population:  2000 and 2010                NaN
# 5  Incorporated Cities by County in Florida                NaN
# 6                                       NaN                NaN
# 7                                       NaN   Total Population
# 8                     State / County / City  April 1, 2000 (2)
# 9                                   Florida           15982824
#
#             Unnamed: 2         Unnamed: 3  \
# 0                  NaN                NaN
# 1                  NaN                NaN
# 2                  NaN                NaN
# 3                  NaN                NaN
# 4                  NaN                NaN
# 5                  NaN                NaN
# 6                  NaN                NaN
# 7                  NaN  Change, 2000-2010
# 8  2010-04-01 00:00:00             Number
# 9             18801310            2818486
#
#                                          Census 2010
# 0  Redistricting Data (Public Law 94-171) Summary...
# 1                             Generated on 3/17/2011
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                            Percent
# 9                                           0.176345

# %%
data.drop([x for x in range(9)], axis=0, inplace=True) #removing the first 8 redundant rows

# %%
data.head()
# Out:
#    Florida Legislative Office of Unnamed: 1 Unnamed: 2 Unnamed: 3 Census 2010
# 9                        Florida   15982824   18801310    2818486    0.176345
# 10                Alachua County     217955     247336      29381    0.134803
# 11                       Alachua       6098       9059       2961    0.485569
# 12                        Archer       1289       1118       -171   -0.132661
# 13                   Gainesville      95447     124354      28907    0.302859

# %%
data.columns = ['Region','2000','2010','Change','Percent']

# %%
data.head()
# Out:
#             Region      2000      2010   Change   Percent
# 9          Florida  15982824  18801310  2818486  0.176345
# 10  Alachua County    217955    247336    29381  0.134803
# 11         Alachua      6098      9059     2961  0.485569
# 12          Archer      1289      1118     -171 -0.132661
# 13     Gainesville     95447    124354    28907  0.302859

# %% [markdown]
# # 2. Creating features

# %% [markdown]
# At this stage we want to extract the County populations to use them as a feature. Therefore, we need to understand which rows are counties.

# %%
def filt(x):#defining a filter to choose the rows with counties
    return 'County' in x #if the string x contains 'County', then the result is true
data['is County'] = data['Region'].apply(filt) #is County = True means the corresponding Region is a county

# %%
data.head()
# Out:
#             Region      2000      2010   Change   Percent  is County
# 9          Florida  15982824  18801310  2818486  0.176345      False
# 10  Alachua County    217955    247336    29381  0.134803       True
# 11         Alachua      6098      9059     2961  0.485569      False
# 12          Archer      1289      1118     -171 -0.132661      False
# 13     Gainesville     95447    124354    28907  0.302859      False

# %%
data = data[data['is County']] #choosing the subdataframe with county rows

# %%
data.head()
# Out:
#              Region    2000    2010 Change    Percent  is County
# 10   Alachua County  217955  247336  29381   0.134803       True
# 20     Baker County   22259   27115   4856   0.218159       True
# 23       Bay County  148217  168852  20635   0.139222       True
# 32  Bradford County   26088   28520   2432  0.0932229       True
# 37   Brevard County  476230  543376  67146   0.140995       True

# %% [markdown]
# At some point we will merge this dataframe with Florida Health Department's beach water test data based on the county column. Therefore, we turn the county names here in to the form they appear in Florida Health Department's beach water test data.

# %%
data['County'] = data['Region'].apply(lambda x: x[:-7]) #creating a column with the county name
#Bay County ---> Bay

# %%
#Here is the list of counties in the current data frame
data.County.unique()
# Out:
# array(['Alachua', 'Baker', 'Bay', 'Bradford', 'Brevard', 'Broward',
#        'Calhoun', 'Charlotte', 'Citrus', 'Clay', 'Collier', 'Columbia',
#        'DeSoto', 'Dixie', 'Duval', 'Escambia', 'Flagler', 'Franklin',
#        'Gadsden', 'Gilchrist', 'Glades', 'Gulf', 'Hamilton', 'Hardee',
#        'Hendry', 'Hernando', 'Highlands', 'Hillsborough', 'Holmes',
#        'Indian River', 'Jackson', 'Jefferson', 'Lafayette', 'Lake', 'Lee',
#        'Leon', 'Levy', 'Liberty', 'Madison', 'Manatee', 'Marion',
#        'Martin', 'Miami-Dade', 'Monroe', 'Nassau', 'Okaloosa',
#        'Okeechobee', 'Orange', 'Osceola', 'Palm Beach', 'Pasco',
#        'Pinellas', 'Polk', 'Putnam', 'St. Johns', 'St. Lucie',
#        'Santa Rosa', 'Sarasota', 'Seminole', 'Sumter', 'Suwannee',
#        'Taylor', 'Union', 'Volusia', 'Wakulla', 'Walton', 'Washington'],
#       dtype=object)

# %%
#Here is the list of coastal counties in the current dataframe
coastal = ['Bay', 'Brevard', 'Broward', 'Charlotte', 'Citrus', 'Collier',
       'Miami-Dade', 'Dixie', 'Duval', 'Escambia', 'Flagler', 'Franklin',
       'Gulf', 'Hernando', 'Hillsborough', 'Indian River', 'Lee', 'Levy',
       'Manatee', 'Martin', 'Monroe', 'Nassau', 'Okaloosa', 'Palm Beach',
       'Pasco', 'Pinellas', 'Santa Rosa', 'Sarasota', 'St. Johns',
       'St. Lucie', 'Taylor', 'Volusia', 'Wakulla', 'Walton']

# %%
#Here is the list of coastal counties in the Florida Health Department's data
county_names = ['Bay', 'Brevard', 'Broward', 'Charlotte', 'Citrus', 'Collier',
       'Dixie', 'Duval', 'Escambia', 'Flagler', 'Franklin', 'Gulf',
       'Hernando', 'Hillsborough', 'Indian River', 'Lee', 'Levy',
       'Manatee', 'Martin', 'Dade', 'Monroe', 'Nassau', 'Okaloosa',
       'Palm Beach', 'Pasco', 'Pinellas', 'St Johns', 'St Lucie',
       'Santa Rosa', 'Sarasota', 'Taylor', 'Volusia', 'Wakulla', 'Walton']

# %%
data.head()
# Out:
#              Region    2000    2010 Change    Percent  is County    County
# 10   Alachua County  217955  247336  29381   0.134803       True   Alachua
# 20     Baker County   22259   27115   4856   0.218159       True     Baker
# 23       Bay County  148217  168852  20635   0.139222       True       Bay
# 32  Bradford County   26088   28520   2432  0.0932229       True  Bradford
# 37   Brevard County  476230  543376  67146   0.140995       True   Brevard

# %%
def fil(x):#defining a filter to choose coastal counties
    return x in coastal

data['is coastal'] = data['County'].apply(fil) #defining a column with boolean
#True means coastal county, False means not a coastal county

# %%
data.head()
# Out:
#              Region    2000    2010 Change    Percent  is County    County  \
# 10   Alachua County  217955  247336  29381   0.134803       True   Alachua
# 20     Baker County   22259   27115   4856   0.218159       True     Baker
# 23       Bay County  148217  168852  20635   0.139222       True       Bay
# 32  Bradford County   26088   28520   2432  0.0932229       True  Bradford
# 37   Brevard County  476230  543376  67146   0.140995       True   Brevard
#
#     is coastal
# 10       False
# 20       False
# 23        True
# 32       False
# 37        True

# %%
new = data[data['is coastal']] #slicing the subdataframe with coastal county entries

# %%
new.columns
# Out:
# Index(['Region', '2000', '2010', 'Change', 'Percent', 'is County', 'County',
#        'is coastal'],
#       dtype='object')

# %%
new.County.unique()
# Out:
# array(['Bay', 'Brevard', 'Broward', 'Charlotte', 'Citrus', 'Collier',
#        'Dixie', 'Duval', 'Escambia', 'Flagler', 'Franklin', 'Gulf',
#        'Hernando', 'Hillsborough', 'Indian River', 'Lee', 'Levy',
#        'Manatee', 'Martin', 'Miami-Dade', 'Monroe', 'Nassau', 'Okaloosa',
#        'Palm Beach', 'Pasco', 'Pinellas', 'St. Johns', 'St. Lucie',
#        'Santa Rosa', 'Sarasota', 'Taylor', 'Volusia', 'Wakulla', 'Walton'],
#       dtype=object)

# %%
new['County'] = county_names #transforming the county names to the format in Florida Health Department's beach test data
# Out:
# /Users/mustafa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new
# Out:
#                   Region     2000     2010  Change     Percent  is County  \
# 23            Bay County   148217   168852   20635    0.139222       True
# 37        Brevard County   476230   543376   67146    0.140995       True
# 54        Broward County  1623018  1748066  125048   0.0770466       True
# 89      Charlotte County   141627   159978   18351    0.129573       True
# 91         Citrus County   118085   141236   23151    0.196054       True
# 99        Collier County   251377   321520   70143    0.279035       True
# 108         Dixie County    13827    16422    2595    0.187676       True
# 111         Duval County   778879   864263   85384    0.109624       True
# 117      Escambia County   294410   297619    3209   0.0108998       True
# 120       Flagler County    49832    95696   45864    0.920372       True
# 126      Franklin County     9829    11549    1720    0.174992       True
# 142          Gulf County    14560    15863    1303   0.0894918       True
# 156      Hernando County   130802   172778   41976    0.320913       True
# 163  Hillsborough County   998948  1229226  230278    0.230521       True
# 173  Indian River County   112947   138028   25081     0.22206       True
# 210           Lee County   440888   618754  177866    0.403427       True
# 218          Levy County    34450    40801    6351    0.184354       True
# 233       Manatee County   264002   322833   58831    0.222843       True
# 246        Martin County   126731   146318   19587    0.154556       True
# 251    Miami-Dade County  2253779  2496435  242656    0.107666       True
# 287        Monroe County    79589    73090   -6499   -0.081657       True
# 293        Nassau County    57663    73314   15651    0.271422       True
# 297      Okaloosa County   170498   180822   10324    0.060552       True
# 326    Palm Beach County  1131191  1320134  188943     0.16703       True
# 365         Pasco County   344768   464697  119929    0.347854       True
# 372      Pinellas County   921495   916542   -4953 -0.00537496       True
# 421     St. Johns County   123135   190039   66904    0.543339       True
# 426     St. Lucie County   192695   277789   85094    0.441599       True
# 430    Santa Rosa County   117743   151372   33629    0.285614       True
# 434      Sarasota County   325961   379448   53487     0.16409       True
# 456        Taylor County    19256    22570    3314    0.172102       True
# 462       Volusia County   443343   494593   51250    0.115599       True
# 480       Wakulla County    22863    30776    7913    0.346105       True
# 483        Walton County    40601    55043   14442    0.355706       True
#
#            County  is coastal
# 23            Bay        True
# 37        Brevard        True
# 54        Broward        True
# 89      Charlotte        True
# 91         Citrus        True
# 99        Collier        True
# 108         Dixie        True
# 111         Duval        True
# 117      Escambia        True
# 120       Flagler        True
# 126      Franklin        True
# 142          Gulf        True
# 156      Hernando        True
# 163  Hillsborough        True
# 173  Indian River        True
# 210           Lee        True
# 218          Levy        True
# 233       Manatee        True
# 246        Martin        True
# 251          Dade        True
# 287        Monroe        True
# 293        Nassau        True
# 297      Okaloosa        True
# 326    Palm Beach        True
# 365         Pasco        True
# 372      Pinellas        True
# 421      St Johns        True
# 426      St Lucie        True
# 430    Santa Rosa        True
# 434      Sarasota        True
# 456        Taylor        True
# 462       Volusia        True
# 480       Wakulla        True
# 483        Walton        True

# %%
for year in range(2000,2021):
    new[str(year)] = new['2000'] + 0.1 * new['Change'] * (year-2000) 
#linearly increasing the population between 2000--->2010--->2020
# Out:
# /Users/mustafa/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new.head()
# Out:
#               Region         2000         2010  Change    Percent  is County  \
# 23        Bay County       148217       168852   20635   0.139222       True
# 37    Brevard County       476230       543376   67146   0.140995       True
# 54    Broward County  1.62302e+06  1.74807e+06  125048  0.0770466       True
# 89  Charlotte County       141627       159978   18351   0.129573       True
# 91     Citrus County       118085       141236   23151   0.196054       True
#
#        County  is coastal         2001         2002  ...         2011  \
# 23        Bay        True       150280       152344  ...       170916
# 37    Brevard        True       482945       489659  ...       550091
# 54    Broward        True  1.63552e+06  1.64803e+06  ...  1.76057e+06
# 89  Charlotte        True       143462       145297  ...       161813
# 91     Citrus        True       120400       122715  ...       143551
#
#            2012         2013         2014         2015         2016  \
# 23       172979       175042       177106       179170       181233
# 37       556805       563520       570234       576949       583664
# 54  1.77308e+06  1.78558e+06  1.79809e+06  1.81059e+06  1.82309e+06
# 89       163648       165483       167318       169154       170989
# 91       145866       148181       150496       152812       155127
#
#           2017        2018         2019         2020
# 23      183296      185360       187424       189487
# 37      590378      597093       603807       610522
# 54  1.8356e+06  1.8481e+06  1.86061e+06  1.87311e+06
# 89      172824      174659       176494       178329
# 91      157442      159757       162072       164387
#
# [5 rows x 27 columns]

# %%
new.columns
# Out:
# Index(['Region', '2000', '2010', 'Change', 'Percent', 'is County', 'County',
#        'is coastal', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020'],
#       dtype='object')

# %%
population = new.drop(['Region', 'Change', 'Percent', 'is County',
       'is coastal'], axis = 1)

# %%
population = population[['County', '2000', '2010', '2001', '2002', '2003', '2004', '2005','2006',
       '2007', '2008', '2009', '2011', '2012', '2013', '2014', '2015', '2016',
       '2017', '2018','2019', '2020']]

# %%
population.head()
# Out:
#        County         2000         2010         2001         2002  \
# 23        Bay       148217       168852       150280       152344
# 37    Brevard       476230       543376       482945       489659
# 54    Broward  1.62302e+06  1.74807e+06  1.63552e+06  1.64803e+06
# 89  Charlotte       141627       159978       143462       145297
# 91     Citrus       118085       141236       120400       122715
#
#            2003         2004         2005         2006         2007  ...  \
# 23       154408       156471       158534       160598       162662  ...
# 37       496374       503088       509803       516518       523232  ...
# 54  1.66053e+06  1.67304e+06  1.68554e+06  1.69805e+06  1.71055e+06  ...
# 89       147132       148967       150802       152638       154473  ...
# 91       125030       127345       129660       131976       134291  ...
#
#            2011         2012         2013         2014         2015  \
# 23       170916       172979       175042       177106       179170
# 37       550091       556805       563520       570234       576949
# 54  1.76057e+06  1.77308e+06  1.78558e+06  1.79809e+06  1.81059e+06
# 89       161813       163648       165483       167318       169154
# 91       143551       145866       148181       150496       152812
#
#            2016        2017        2018         2019         2020
# 23       181233      183296      185360       187424       189487
# 37       583664      590378      597093       603807       610522
# 54  1.82309e+06  1.8356e+06  1.8481e+06  1.86061e+06  1.87311e+06
# 89       170989      172824      174659       176494       178329
# 91       155127      157442      159757       162072       164387
#
# [5 rows x 22 columns]

# %% [markdown]
# Finally we obtained the population of each coastal county on a given year between 2000-2020.

# %%
popu_melt = pd.melt(frame=population,id_vars='County') #turning the year data into a column
popu_melt.columns = ['County', 'Year', 'Population'] #defining columns
popu_melt.sort_values(by='County')
# Out:
#       County  Year Population
# 0        Bay  2000     148217
# 68       Bay  2001     150280
# 646      Bay  2019     187424
# 102      Bay  2002     152344
# 612      Bay  2018     185360
# 136      Bay  2003     154408
# 578      Bay  2017     183296
# 170      Bay  2004     156471
# 544      Bay  2016     181233
# 204      Bay  2005     158534
# 510      Bay  2015     179170
# 238      Bay  2006     160598
# 476      Bay  2014     177106
# 272      Bay  2007     162662
# 442      Bay  2013     175042
# 306      Bay  2008     164725
# 408      Bay  2012     172979
# 340      Bay  2009     166788
# 680      Bay  2020     189487
# 34       Bay  2010     168852
# 374      Bay  2011     170916
# 647  Brevard  2019     603807
# 171  Brevard  2004     503088
# 409  Brevard  2012     556805
# 545  Brevard  2016     583664
# 579  Brevard  2017     590378
# 205  Brevard  2005     509803
# 443  Brevard  2013     563520
# 511  Brevard  2015     576949
# 239  Brevard  2006     516518
# ..       ...   ...        ...
# 474  Wakulla  2013    33149.9
# 576  Wakulla  2016    35523.8
# 508  Wakulla  2014    33941.2
# 610  Wakulla  2017    36315.1
# 168  Wakulla  2003    25236.9
# 644  Wakulla  2018    37106.4
# 66   Wakulla  2010      30776
# 202  Wakulla  2004    26028.2
# 542  Wakulla  2015    34732.5
# 67    Walton  2010      55043
# 33    Walton  2000      40601
# 373   Walton  2009    53598.8
# 611   Walton  2017    65152.4
# 101   Walton  2001    42045.2
# 645   Walton  2018    66596.6
# 339   Walton  2008    52154.6
# 305   Walton  2007    50710.4
# 577   Walton  2016    63708.2
# 407   Walton  2011    56487.2
# 169   Walton  2003    44933.6
# 543   Walton  2015      62264
# 441   Walton  2012    57931.4
# 271   Walton  2006    49266.2
# 203   Walton  2004    46377.8
# 509   Walton  2014    60819.8
# 237   Walton  2005      47822
# 475   Walton  2013    59375.6
# 679   Walton  2019    68040.8
# 135   Walton  2002    43489.4
# 713   Walton  2020      69485
#
# [714 rows x 3 columns]

# %%
popu_melt.County.unique() #looks like we have the right county names.
# Out:
# array(['Bay', 'Brevard', 'Broward', 'Charlotte', 'Citrus', 'Collier',
#        'Dixie', 'Duval', 'Escambia', 'Flagler', 'Franklin', 'Gulf',
#        'Hernando', 'Hillsborough', 'Indian River', 'Lee', 'Levy',
#        'Manatee', 'Martin', 'Dade', 'Monroe', 'Nassau', 'Okaloosa',
#        'Palm Beach', 'Pasco', 'Pinellas', 'St Johns', 'St Lucie',
#        'Santa Rosa', 'Sarasota', 'Taylor', 'Volusia', 'Wakulla', 'Walton'],
#       dtype=object)

# %%
popu_melt.to_csv('YearlyCountyPopulation.csv', encoding='utf-8', index=False)
